# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

print("Everything is working 👍🏻")
# Out:
# Everything is working 👍🏻

# %%
df=pd.read_csv('SuperMarketAnalysis.csv')

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428   Alex     Yangon        Member  Female
# 1  226-31-3081   Giza  Naypyitaw        Normal  Female
# 2  631-41-3108   Alex     Yangon        Normal  Female
# 3  123-19-1176   Alex     Yangon        Member  Female
# 4  373-73-7910   Alex     Yangon        Member  Female
# 5  699-14-3026   Giza  Naypyitaw        Member  Female
# 6  355-53-5943   Alex     Yangon        Member  Female
# 7  315-22-5665   Giza  Naypyitaw        Member  Female
# 8  665-32-9167   Alex     Yangon        Member  Female
# 9  692-92-5582  Cairo   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Sales       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
df.tail(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227  Cairo   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313   Alex     Yangon        Member    Male   Food and beverages
# 998  347-56-2442   Alex     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807   Alex     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Sales       Date        Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  1:46:00 PM  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  5:16:00 PM  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  1:22:00 PM     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  3:33:00 PM     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  1:28:00 PM     Cash
#
# ...

# %% [markdown]
# name of all columns

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Sales', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='str')

# %% [markdown]
# find data type of each columns

# %%
df.dtypes
# Out:
# Invoice ID                     str
# Branch                         str
# City                           str
# Customer type                  str
# Gender                         str
# Product line                   str
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Sales                      float64
# Date                           str
# Time                           str
# Payment                        str
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# check whether there is any missin value
# sum() will give column wise

# %%
# print(df.isna().sum())
print(df.isna().sum().sum())
# Out:
# 0

# %% [markdown]
# number of unique values in each columns

# %%
df.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Sales                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %% [markdown]
# nu,ber of unique cities

# %%
df['City'].nunique()
# Out:
# 3

# %% [markdown]
# number of unique product pines

# %%
df['Product line'].nunique()
# Out:
# 6

# %% [markdown]
# number of unique payment modes

# %%
df['Payment'].nunique()
# Out:
# 3

# %% [markdown]
# how many transactions came form each city

# %%
df['City'].value_counts()
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %% [markdown]
# how many transactions from each branch

# %%
df['Branch'].value_counts()
# Out:
# Branch
# Alex     340
# Cairo    332
# Giza     328
# Name: count, dtype: int64

# %% [markdown]
# from each customer type

# %%
df['Customer type'].value_counts()
# Out:
# Customer type
# Member    565
# Normal    435
# Name: count, dtype: int64

# %% [markdown]
# made by each gender

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    571
# Male      429
# Name: count, dtype: int64

# %% [markdown]
# belongs to each product line

# %%
df['Product line'].value_counts()
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %% [markdown]
# how many transactiosn use each payment method

# %%
df['Payment'].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %% [markdown]
# which product line has the most transaction

# %%
df['Product line'].value_counts().idxmax()
# Out:
# 'Fashion accessories'

# %% [markdown]
# Which payment method was used most

# %%
df['Payment'].value_counts().idxmax()
# Out:
# 'Ewallet'

# %% [markdown]
# Which city has most transaction

# %%
df['City'].value_counts().idxmax()
# Out:
# 'Yangon'

# %% [markdown]
# which customer appears most

# %%
df['Customer type'].value_counts().idxmax()
# Out:
# 'Member'

# %% [markdown]
# What is the average unit price

# %%
print(df['Unit price'].mean())
# Out:
# 55.67213

# %% [markdown]
# what is the average quatity purchase

# %%
print(df['Quantity'].mean())
# Out:
# 5.51

# %% [markdown]
# avergae total sales amount

# %%
print(df['Sales'].mean())
# Out:
# 322.966749

# %% [markdown]
# maximum total sale

# %%
print(df['Sales'].max())
# Out:
# 1042.65

# %% [markdown]
# minimum total sale

# %%
print(df['Sales'].min())
# Out:
# 10.6785

# %% [markdown]
# total revenue

# %%
print(df['Sales'].sum())
# Out:
# 322966.749

# %% [markdown]
# total gross income

# %%
print(df['gross income'].sum())
# Out:
# 15379.368999999999

# %% [markdown]
# highest rated transaction

# %%
print(df['Rating'].max())
# Out:
# 10.0

# %% [markdown]
# average customer rating

# %%
print(df['Rating'].mean())
# Out:
# 6.9727

# %% [markdown]
# total quatity of products sold

# %%
print(df['Quantity'].sum())
# Out:
# 5510

# %% [markdown]
# Find all transactions where

# %% [markdown]
# qunatity is greater than 5

# %%
df[df['Quantity']>7]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 3    123-19-1176   Alex     Yangon        Member  Female
# 7    315-22-5665   Giza  Naypyitaw        Member  Female
# 13   252-56-2699   Alex     Yangon        Member  Female
# 14   829-34-3910   Alex     Yangon        Member  Female
# 25   227-03-5010   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 988  267-62-7380   Giza  Naypyitaw        Member    Male
# 989  430-53-4718  Cairo   Mandalay        Member    Male
# 991  602-16-6955  Cairo   Mandalay        Normal  Female
# 993  690-01-6631  Cairo   Mandalay        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity  Tax 5%     Sales  \
# 3         Health and beauty       58.22         8  23.288   489.048
# 7        Home and lifestyle       73.56        10  36.780   772.380
# 13       Food and beverages       43.19        10  21.595   453.495
# ...

# %% [markdown]
# total is greater than 500

# %%
df[df['Sales']>500]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# 5    699-14-3026   Giza  Naypyitaw        Member  Female
# 7    315-22-5665   Giza  Naypyitaw        Member  Female
# 14   829-34-3910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 988  267-62-7380   Giza  Naypyitaw        Member    Male
# 989  430-53-4718  Cairo   Mandalay        Member    Male
# 991  602-16-6955  Cairo   Mandalay        Normal  Female
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ...

# %% [markdown]
# from YanGon

# %%
df.loc[df['City']=='Yangon']
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428   Alex  Yangon        Member  Female       Health and beauty
# 2    631-41-3108   Alex  Yangon        Normal  Female      Home and lifestyle
# 3    123-19-1176   Alex  Yangon        Member  Female       Health and beauty
# 4    373-73-7910   Alex  Yangon        Member  Female       Sports and travel
# 6    355-53-5943   Alex  Yangon        Member  Female  Electronic accessories
# ..           ...    ...     ...           ...     ...                     ...
# 990  886-18-2897   Alex  Yangon        Normal  Female      Food and beverages
# 992  745-74-0715   Alex  Yangon        Normal    Male  Electronic accessories
# 997  727-02-1313   Alex  Yangon        Member    Male      Food and beverages
# 998  347-56-2442   Alex  Yangon        Normal    Male      Home and lifestyle
# 999  849-09-3807   Alex  Yangon        Member  Female     Fashion accessories
#
# ...

# %% [markdown]
# made by members

# %%
df.loc[df['Customer type']=='Member']
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# 5    699-14-3026   Giza  Naypyitaw        Member  Female
# 6    355-53-5943   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 988  267-62-7380   Giza  Naypyitaw        Member    Male
# 989  430-53-4718  Cairo   Mandalay        Member    Male
# 994  652-49-6720   Giza  Naypyitaw        Member  Female
# 997  727-02-1313   Alex     Yangon        Member    Male
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Sales  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 3         Health and beauty       58.22         8  23.2880  489.0480
# 4         Sports and travel       86.31         7  30.2085  634.3785
# ...

# %% [markdown]
# payment methos is ewallet

# %%
df.loc[df['Payment']=='Ewallet']
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# 5    699-14-3026   Giza  Naypyitaw        Member  Female
# 6    355-53-5943   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 992  745-74-0715   Alex     Yangon        Normal    Male
# 993  690-01-6631  Cairo   Mandalay        Normal    Male
# 994  652-49-6720   Giza  Naypyitaw        Member  Female
# 995  233-67-5758   Giza  Naypyitaw        Normal    Male
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 3         Health and beauty       58.22         8  23.2880   489.0480
# ...

# %% [markdown]
# from food and beverage product line

# %%
df.loc[df['Product line']=="Food and beverages"]
# Out:
#       Invoice ID Branch       City Customer type  Gender        Product line  \
# 9    692-92-5582  Cairo   Mandalay        Member  Female  Food and beverages
# 13   252-56-2699   Alex     Yangon        Member  Female  Food and beverages
# 18   329-62-1586   Alex     Yangon        Member  Female  Food and beverages
# 28   145-94-9061  Cairo   Mandalay        Member  Female  Food and beverages
# 34   183-56-6882   Giza  Naypyitaw        Member  Female  Food and beverages
# ..           ...    ...        ...           ...     ...                 ...
# 977  518-71-6847  Cairo   Mandalay        Member    Male  Food and beverages
# 979  151-33-7434  Cairo   Mandalay        Normal  Female  Food and beverages
# 980  728-47-9078   Giza  Naypyitaw        Member    Male  Food and beverages
# 990  886-18-2897   Alex     Yangon        Normal  Female  Food and beverages
# 997  727-02-1313   Alex     Yangon        Member    Male  Food and beverages
#
# ...

# %% [markdown]
# rating is greater than 8

# %%
df.loc[df['Rating']>8]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 1    226-31-3081   Giza  Naypyitaw        Normal  Female
# 3    123-19-1176   Alex     Yangon        Member  Female
# 13   252-56-2699   Alex     Yangon        Member  Female
# 18   329-62-1586   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 980  728-47-9078   Giza  Naypyitaw        Member    Male
# 981  809-46-1866   Alex     Yangon        Normal    Male
# 985  374-38-5555  Cairo   Mandalay        Normal  Female
# 989  430-53-4718  Cairo   Mandalay        Member    Male
# 992  745-74-0715   Alex     Yangon        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Sales  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200   80.2200
# 3         Health and beauty       58.22         8  23.2880  489.0480
# ...

# %% [markdown]
# quatity is greater than 5 and total is greter than 500

# %%
df.loc[(df['Quantity']>5) & (df['Sales']>500)]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428   Alex     Yangon        Member  Female
# 4    373-73-7910   Alex     Yangon        Member  Female
# 5    699-14-3026   Giza  Naypyitaw        Member  Female
# 7    315-22-5665   Giza  Naypyitaw        Member  Female
# 14   829-34-3910   Alex     Yangon        Member  Female
# ..           ...    ...        ...           ...     ...
# 988  267-62-7380   Giza  Naypyitaw        Member    Male
# 989  430-53-4718  Cairo   Mandalay        Member    Male
# 991  602-16-6955  Cairo   Mandalay        Normal  Female
# 996  303-96-2227  Cairo   Mandalay        Normal  Female
# 999  849-09-3807   Alex     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Sales  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ...

# %% [markdown]
# from yangon where customer is member

# %%
df.loc[(df['City']=='Yangon') & (df['Customer type']=='Member')]
# Out:
#       Invoice ID Branch    City Customer type  Gender            Product line  \
# 0    750-67-8428   Alex  Yangon        Member  Female       Health and beauty
# 3    123-19-1176   Alex  Yangon        Member  Female       Health and beauty
# 4    373-73-7910   Alex  Yangon        Member  Female       Sports and travel
# 6    355-53-5943   Alex  Yangon        Member  Female  Electronic accessories
# 8    665-32-9167   Alex  Yangon        Member  Female       Health and beauty
# ..           ...    ...     ...           ...     ...                     ...
# 961  324-92-3863   Alex  Yangon        Member    Male  Electronic accessories
# 967  195-06-0432   Alex  Yangon        Member    Male      Home and lifestyle
# 982  139-32-4183   Alex  Yangon        Member  Female       Sports and travel
# 997  727-02-1313   Alex  Yangon        Member    Male      Food and beverages
# 999  849-09-3807   Alex  Yangon        Member  Female     Fashion accessories
#
# ...

# %% [markdown]
# where the payment is credit card and rating is greter than 7

# %%
df.loc[(df['Payment']=='Credit card' ) & (df['Rating']>7)]
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 2    631-41-3108   Alex    Yangon        Normal  Female
# 8    665-32-9167   Alex    Yangon        Member  Female
# 18   329-62-1586   Alex    Yangon        Member  Female
# 25   227-03-5010   Alex    Yangon        Member  Female
# 27   189-17-4241   Alex    Yangon        Member  Female
# ..           ...    ...       ...           ...     ...
# 962  593-08-5916   Alex    Yangon        Normal  Female
# 967  195-06-0432   Alex    Yangon        Member    Male
# 969  214-30-2776  Cairo  Mandalay        Member  Female
# 970  746-04-1077  Cairo  Mandalay        Member  Female
# 989  430-53-4718  Cairo  Mandalay        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Sales  \
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# 8         Health and beauty       36.26         2   3.6260   76.1460
# 18       Food and beverages       54.67         3   8.2005  172.2105
# ...

# %% [markdown]
# total sales for each city

# %%
df.groupby('City')['Sales'].sum()
# Out:
# City
# Mandalay     106197.6720
# Naypyitaw    110568.7065
# Yangon       106200.3705
# Name: Sales, dtype: float64

# %% [markdown]
# average sales for each city

# %%
df.groupby('City')['Sales'].mean()
# Out:
# City
# Mandalay     319.872506
# Naypyitaw    337.099715
# Yangon       312.354031
# Name: Sales, dtype: float64

# %% [markdown]
# total sales for each product line

# %%
df.groupby('Product line')['Sales'].sum()
# Out:
# Product line
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Food and beverages        56144.8440
# Health and beauty         49193.7390
# Home and lifestyle        53861.9130
# Sports and travel         55122.8265
# Name: Sales, dtype: float64

# %% [markdown]
# average rating for each product line

# %%
df.groupby('Product line')['Rating'].mean()
# Out:
# Product line
# Electronic accessories    6.924706
# Fashion accessories       7.029213
# Food and beverages        7.113218
# Health and beauty         7.003289
# Home and lifestyle        6.837500
# Sports and travel         6.916265
# Name: Rating, dtype: float64

# %% [markdown]
# total quatity sold for eadh produvt line

# %%
df.groupby('Product line')['Quantity'].sum()
# Out:
# Product line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: Quantity, dtype: int64

# %% [markdown]
# average unit price for each product line

# %%
df.groupby('Product line')['Unit price'].mean()
# df.head()
# Out:
# Product line
# Electronic accessories    53.551588
# Fashion accessories       57.153652
# Food and beverages        56.008851
# Health and beauty         54.854474
# Home and lifestyle        55.316937
# Sports and travel         56.993253
# Name: Unit price, dtype: float64

# %% [markdown]
# total gross income of each branch

# %%
df.groupby('Branch')['gross income'].sum()
# Out:
# Branch
# Alex     5057.1605
# Cairo    5057.0320
# Giza     5265.1765
# Name: gross income, dtype: float64

# %% [markdown]
# total sales for each payment method

# %%
df.groupby('Payment')['Sales'].sum()
# Out:
# Payment
# Cash           112206.570
# Credit card    100767.072
# Ewallet        109993.107
# Name: Sales, dtype: float64

# %% [markdown]
# average sales for each each customer type

# %%
df.groupby('Customer type')['Sales'].mean()
# Out:
# Customer type
# Member    335.742945
# Normal    306.372379
# Name: Sales, dtype: float64

# %% [markdown]
# city generated highest total sales

# %%
df.groupby('City')['Sales'].sum().idxmax()
# Out:
# 'Naypyitaw'

# %% [markdown]
# product lien generated highest total sales

# %%
df.groupby('Product line')['Sales'].sum().idxmax()
# Out:
# 'Food and beverages'

# %% [markdown]
# branch generated highest gross income

# %%
df.groupby('Branch')['gross income'].sum().idxmax()
# df.head()
# Out:
# 'Giza'

# %% [markdown]
# produxt line has highest average rating

# %%
df.groupby('Product line')['Rating'].mean().idxmax()
# Out:
# 'Food and beverages'

# %% [markdown]
# payment method generated highest total sales

# %%
df.groupby('Payment')['Sales'].sum().idxmax()
# Out:
# 'Cash'

# %% [markdown]
# customer type has highest average transaction value

# %%
df.groupby('Customer type')['Sales'].mean().idxmax()
# df.head()
# Out:
# 'Member'

# %% [markdown]
# product line solde the highest total quantity

# %%
df.groupby('Product line')['Quantity'].sum().idxmax()
# Out:
# 'Electronic accessories'

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428   Alex     Yangon        Member  Female
# 1  226-31-3081   Giza  Naypyitaw        Normal  Female
# 2  631-41-3108   Alex     Yangon        Normal  Female
# 3  123-19-1176   Alex     Yangon        Member  Female
# 4  373-73-7910   Alex     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Sales       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#           Time      Payment    cogs  gross margin percentage  gross income  \
# 0   1:08:00 PM      Ewallet  522.83                 4.761905       26.1415
# ...

# %% [markdown]
# total sales of each city and product line

# %%
df.groupby(['City','Product line'])['Sales'].sum()
# Out:
# City       Product line
# Mandalay   Electronic accessories    17051.4435
#            Fashion accessories       16413.3165
#            Food and beverages        15214.8885
#            Health and beauty         19980.6600
#            Home and lifestyle        17549.1645
#            Sports and travel         19988.1990
# Naypyitaw  Electronic accessories    18968.9745
#            Fashion accessories       21560.0700
#            Food and beverages        23766.8550
#            Health and beauty         16615.3260
#            Home and lifestyle        13895.5530
#            Sports and travel         15761.9280
# Yangon     Electronic accessories    18317.1135
#            Fashion accessories       16332.5085
#            Food and beverages        17163.1005
#            Health and beauty         12597.7530
#            Home and lifestyle        22417.1955
#            Sports and travel         19372.6995
# Name: Sales, dtype: float64

# %% [markdown]
# average sales for each city adn product line

# %%
df.groupby(['City','Product line'])['Sales'].mean()
# Out:
# City       Product line
# Mandalay   Electronic accessories    310.026245
#            Fashion accessories       264.730911
#            Food and beverages        304.297770
#            Health and beauty         376.993585
#            Home and lifestyle        350.983290
#            Sports and travel         322.390306
# Naypyitaw  Electronic accessories    344.890445
#            Fashion accessories       331.693385
#            Food and beverages        360.103864
#            Health and beauty         319.525500
#            Home and lifestyle        308.790067
#            Sports and travel         350.265067
# Yangon     Electronic accessories    305.285225
#            Fashion accessories       320.245265
#            Food and beverages        295.915526
#            Health and beauty         268.037298
#            Home and lifestyle        344.879931
#            Sports and travel         328.350839
# Name: Sales, dtype: float64

# %% [markdown]
# total quantity sold by each gender fro each product line

# %%
df.groupby(['Gender','Product line'])['Quantity'].sum()
# Out:
# Gender  Product line
# Female  Electronic accessories    548
#         Fashion accessories       586
#         Food and beverages        568
#         Health and beauty         425
#         Home and lifestyle        561
#         Sports and travel         600
# Male    Electronic accessories    423
#         Fashion accessories       316
#         Food and beverages        384
#         Health and beauty         429
#         Home and lifestyle        350
#         Sports and travel         320
# Name: Quantity, dtype: int64

# %% [markdown]
# average rating for each customer type and gender

# %%
df.groupby(['Customer type','Gender'])['Rating'].mean()
# Out:
# Customer type  Gender
# Member         Female    6.887079
#                Male      6.968421
# Normal         Female    7.080000
#                Male      7.010455
# Name: Rating, dtype: float64

# %% [markdown]
# total sales for each branch and payment mode

# %%
df.groupby(['Branch','Payment'])['Sales'].max()
# Out:
# Branch  Payment
# Alex    Cash            932.337
#         Credit card    1039.290
#         Ewallet         951.825
# Cairo   Cash            867.090
#         Credit card    1022.385
#         Ewallet        1022.490
# Giza    Cash           1003.590
#         Credit card    1042.650
#         Ewallet        1034.460
# Name: Sales, dtype: float64

# %% [markdown]
# avegare total sales of each city and customer type

# %%
df.groupby(['Customer type','City'])['Sales'].mean()
# Out:
# Customer type  City
# Member         Mandalay     330.520276
#                Naypyitaw    345.231015
#                Yangon       331.030405
# Normal         Mandalay     307.109285
#                Naypyitaw    325.327534
#                Yangon       288.697290
# Name: Sales, dtype: float64

# %% [markdown]
# which city and product combination generate highest sales

# %%
df.groupby(['City','Product line'])['Sales'].sum().idxmax()
# Out:
# ('Naypyitaw', 'Food and beverages')

# %% [markdown]
# total from highest to lowest

# %%
df.sort_values('Sales')
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 822  784-21-9238   Giza  Naypyitaw        Member    Male    Sports and travel
# 629  308-39-1707   Alex     Yangon        Normal  Female  Fashion accessories
# 223  279-62-1445   Giza  Naypyitaw        Member  Female  Fashion accessories
# 443  192-98-7397   Giza  Naypyitaw        Normal    Male  Fashion accessories
# 402  236-86-3015   Giza  Naypyitaw        Member    Male   Home and lifestyle
# ..           ...    ...        ...           ...     ...                  ...
# 996  303-96-2227  Cairo   Mandalay        Normal  Female   Home and lifestyle
# 699  751-41-9720   Giza  Naypyitaw        Normal    Male   Home and lifestyle
# 557  283-26-5248   Giza  Naypyitaw        Member  Female   Food and beverages
# 167  687-47-8271   Alex     Yangon        Normal    Male  Fashion accessories
# 350  860-79-0874   Giza  Naypyitaw        Member  Female  Fashion accessories
#
# ...

# %% [markdown]
# top 10 by total sales

# %%
df.sort_values('Sales',ascending=False).head(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874   Giza  Naypyitaw        Member  Female  Fashion accessories
# 167  687-47-8271   Alex     Yangon        Normal    Male  Fashion accessories
# 557  283-26-5248   Giza  Naypyitaw        Member  Female   Food and beverages
# 699  751-41-9720   Giza  Naypyitaw        Normal    Male   Home and lifestyle
# 996  303-96-2227  Cairo   Mandalay        Normal  Female   Home and lifestyle
# 792  744-16-7898  Cairo   Mandalay        Normal  Female   Home and lifestyle
# 422  271-88-8734   Giza  Naypyitaw        Member  Female  Fashion accessories
# 166  234-65-2137   Giza  Naypyitaw        Normal    Male   Home and lifestyle
# 357  554-42-2417   Giza  Naypyitaw        Normal  Female    Sports and travel
# 429  325-77-6186   Alex     Yangon        Member  Female   Home and lifestyle
#
#      Unit price  Quantity  Tax 5%     Sales       Date         Time  \
# ...

# %% [markdown]
# bottm 10 by total sales

# %%
df.sort_values('Sales').head(10)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 822  784-21-9238   Giza  Naypyitaw        Member    Male    Sports and travel
# 629  308-39-1707   Alex     Yangon        Normal  Female  Fashion accessories
# 223  279-62-1445   Giza  Naypyitaw        Member  Female  Fashion accessories
# 443  192-98-7397   Giza  Naypyitaw        Normal    Male  Fashion accessories
# 402  236-86-3015   Giza  Naypyitaw        Member    Male   Home and lifestyle
# 282  490-29-1201   Alex     Yangon        Normal  Female    Sports and travel
# 53   778-71-5554   Giza  Naypyitaw        Member  Female  Fashion accessories
# 962  593-08-5916   Alex     Yangon        Normal  Female  Fashion accessories
# 424  489-64-4354   Giza  Naypyitaw        Normal    Male  Fashion accessories
# 808  559-61-5987  Cairo   Mandalay        Normal  Female    Health and beauty
#
#      Unit price  Quantity  Tax 5%    Sales       Date         Time  \
# ...

# %% [markdown]
# product line accorsing to total sales

# %%
df.groupby('Product line')['Sales'].sum().sort_values()
# Out:
# Product line
# Health and beauty         49193.7390
# Home and lifestyle        53861.9130
# Fashion accessories       54305.8950
# Electronic accessories    54337.5315
# Sports and travel         55122.8265
# Food and beverages        56144.8440
# Name: Sales, dtype: float64

# %% [markdown]
# city accorsing to average sales

# %%
df.groupby('City')['Sales'].mean().sort_values()
# Out:
# City
# Yangon       312.354031
# Mandalay     319.872506
# Naypyitaw    337.099715
# Name: Sales, dtype: float64

# %% [markdown]
# top 5 transactions with gighest gross income

# %%
df.sort_values('gross income',ascending=False).head(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874   Giza  Naypyitaw        Member  Female  Fashion accessories
# 167  687-47-8271   Alex     Yangon        Normal    Male  Fashion accessories
# 557  283-26-5248   Giza  Naypyitaw        Member  Female   Food and beverages
# 699  751-41-9720   Giza  Naypyitaw        Normal    Male   Home and lifestyle
# 996  303-96-2227  Cairo   Mandalay        Normal  Female   Home and lifestyle
#
#      Unit price  Quantity  Tax 5%    Sales       Date        Time  \
# 350       99.30        10   49.65  1042.65  2/15/2019  2:53:00 PM
# 167       98.98        10   49.49  1039.29   2/8/2019  4:20:00 PM
# 557       98.52        10   49.26  1034.46  1/30/2019  8:23:00 PM
# 699       97.50        10   48.75  1023.75  1/12/2019  4:18:00 PM
# 996       97.38        10   48.69  1022.49   3/2/2019  5:16:00 PM
#
#          Payment   cogs  gross margin percentage  gross income  Rating
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Date'].min()
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2019-03-30 00:00:00')

# %%
df['Month']=df['Date'].dt.month
df['Month']
# Out:
# 0      1
# 1      3
# 2      3
# 3      1
# 4      2
#       ..
# 995    1
# 996    3
# 997    2
# 998    2
# 999    2
# Name: Month, Length: 1000, dtype: int32

# %%
df['Date'].value_counts()
# Out:
# Date
# 2019-02-07    20
# 2019-02-15    19
# 2019-03-02    18
# 2019-01-08    18
# 2019-03-14    18
#               ..
# 2019-02-01     6
# 2019-01-04     6
# 2019-03-21     6
# 2019-02-21     6
# 2019-03-17     6
# Name: count, Length: 89, dtype: int64

# %%
df.groupby('Date')['Sales'].sum()
# Out:
# Date
# 2019-01-01    4745.1810
# 2019-01-02    1945.5030
# 2019-01-03    2078.1285
# 2019-01-04    1623.6885
# 2019-01-05    3536.6835
#                 ...
# 2019-03-26    1962.5130
# 2019-03-27    2902.8195
# 2019-03-28    2229.4020
# 2019-03-29    4023.2430
# 2019-03-30    4487.0595
# Name: Sales, Length: 89, dtype: float64

# %%
df.groupby('Date')['Sales'].sum().idxmax()
# Out:
# Timestamp('2019-03-09 00:00:00')

# %%
df.groupby('Date')['Sales'].mean()
# Out:
# Date
# 2019-01-01    395.431750
# 2019-01-02    243.187875
# 2019-01-03    259.766062
# 2019-01-04    270.614750
# 2019-01-05    294.723625
#                  ...
# 2019-03-26    150.962538
# 2019-03-27    290.281950
# 2019-03-28    222.940200
# 2019-03-29    502.905375
# 2019-03-30    407.914500
# Name: Sales, Length: 89, dtype: float64
